# %% [markdown]
# ### Máster en Ciencia de Datos - CUNEF
#
# ### Trabajo Final de Máster
#
# ### Detección de transacciones fraudulentas con tarjetas bancarias usando técnicas de clasificación
#
# Alba Rodríguez Berenguel

# %% [markdown]
# En este notebook se va a construir el modelo LightGBM.
#
# Se van a realizar distintas pruebas para ver qué funciona mejor. Primero se realizará un modelo con el dataset completo y después con las distintas técnicas de feature selection que se han aplicado, para comprobar si se puede disminuir el número de variables y no afecta a la predicción. Después se probarán distintas técnicas para dataset desbalanceados como SMOTE, RandomUndersampler y SMOTETomek. Los pasos que se van a seguir son los siguientes:
#
# 1. Importación de librerías, funciones y datos.
# 2. Modelo inicial
# 3. Modelos con Feature Selection
# 4. Modelos con técnicas para dataset desbalanceados
# 5. Exportación del mejor modelo

# %% [markdown]
# ## 1. Importación de librerías, funciones y datos

# %%
# Import libraries.
import pandas as pd
import matplotlib.pyplot as plt
import pickle 
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.metrics import ConfusionMatrixDisplay, fbeta_score
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, accuracy_score, classification_report
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import RandomUnderSampler
#from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import scikitplot as skplt
from sklearn.inspection import PartialDependenceDisplay
import warnings
warnings.filterwarnings('ignore')

# %%
# Function to evaluate the model.
def evaluate_model(ytest, ypred, ypred_proba = None):
    if ypred_proba is not None:
        print('ROC-AUC score of the model: {}'.format(roc_auc_score(ytest, ypred_proba[:, 1])))
    print('Accuracy of the model: {}\n'.format(accuracy_score(ytest, ypred)))
    print('Classification report: \n{}\n'.format(classification_report(ytest, ypred)))
    print('Confusion Matrix: \n{}\n'.format(confusion_matrix(y_test, pred)))

# %%
# Load data.
X_train = pd.read_parquet("../data/processed/X_train.parquet")
y_train = pd.read_parquet("../data/processed/y_train.parquet")['isfraud']

X_test = pd.read_parquet("../data/processed/X_test.parquet")
y_test = pd.read_parquet("../data/processed/y_test.parquet")['isfraud']

X_train_boruta = pd.read_parquet("../data/processed/X_train_boruta.parquet")
X_test_boruta = pd.read_parquet("../data/processed/X_test_boruta.parquet")

X_train_rfe = pd.read_parquet("../data/processed/X_train_rfe.parquet")
X_test_rfe = pd.read_parquet("../data/processed/X_test_rfe.parquet")

X_train_lasso1 = pd.read_parquet("../data/processed/X_train_lasso1.parquet")
X_test_lasso1 = pd.read_parquet("../data/processed/X_test_lasso1.parquet")

X_train_lasso2 = pd.read_parquet("../data/processed/X_train_lasso2.parquet")
X_test_lasso2 = pd.read_parquet("../data/processed/X_test_lasso2.parquet")

# %%
# Import the preprocessor.
preprocessor = pickle.load(open('../models/preprocessor.pickle', 'rb'))

# %% [markdown]
# ## 2. Modelo inicial

# %%
# Classifier.
classifier = lgb.LGBMClassifier(n_jobs=-1, random_state=0, scale_pos_weight=9.75)

lgbm = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', classifier)   
])

# %%
lgbm.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('catohe',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['productcd', 'card4',
#                                                    'card6', 'm4']),
#                                                  ('catbin',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=-1,
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OrdinalEncoder())]),
#                                                   ['m...
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=-99,
#                                                                                  strategy='constant')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['transactionamt', 'c1', 'c3',
#                                                    'c5', 'd1', 'd3', 'd4',
#                                                    'd10', 'd11', 'd15', 'v3',
#                                                    'v4', 'v6', 'v8', 'v11',
#                                                    'v13', 'v17', 'v20', 'v23',
#                                                    'v26', 'v27', 'v30', 'v36',
#                                                    'v37', 'v40', 'v44', 'v47',
#                                                    'v48', 'v54', 'v56', ...])])),
#                 ('classifier',
#                  LGBMClassifier(random_state=0, scale_pos_weight=9.75))])

# %%
# Predictions of target value for the validation set.
pred = lgbm.predict(X_test)

# Predictions of probabilities of the target value for the validation set.
pred_proba = lgbm.predict_proba(X_test)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.9221042187840067
# Accuracy of the model: 0.9496532193790168
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97    113837
#            1       0.37      0.66      0.48      4105
#
#     accuracy                           0.95    117942
#    macro avg       0.68      0.81      0.73    117942
# weighted avg       0.97      0.95      0.96    117942
#
#
# Confusion Matrix:
# [[109295   4542]
#  [  1396   2709]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve LightGBM')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ## 3. Modelo con Feature Selection

# %% [markdown]
# ### 3.1. Boruta

# %%
# Classifier.
classifier = lgb.LGBMClassifier(n_jobs=-1, random_state=0, boosting_type='gbdt', objective='binary', metric='auc',
                               learning_rate=0.1, scale_pos_weight=9.75)

lgbm_boruta = Pipeline([
    ('classifier', classifier)   
])

# %%
lgbm_boruta.fit(X_train_boruta, y_train)
# Out:
# Pipeline(steps=[('classifier',
#                  LGBMClassifier(metric='auc', objective='binary',
#                                 random_state=0, scale_pos_weight=9.75))])

# %%
# Predictions of target value for the validation set.
pred = lgbm_boruta.predict(X_test_boruta)

# Predictions of probabilities of the target value for the validation set.
pred_proba = lgbm_boruta.predict_proba(X_test_boruta)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.9224454357710024
# Accuracy of the model: 0.9496362618914381
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97    113837
#            1       0.37      0.66      0.48      4105
#
#     accuracy                           0.95    117942
#    macro avg       0.68      0.81      0.73    117942
# weighted avg       0.97      0.95      0.96    117942
#
#
# Confusion Matrix:
# [[109274   4563]
#  [  1377   2728]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve LightGBM')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ### 3.2. RFE

# %%
# Classifier.
classifier = lgb.LGBMClassifier(n_jobs=-1, random_state=0, boosting_type='gbdt', objective='binary', metric='auc', 
                                learning_rate=0.1, scale_pos_weight=9.75)

lgbm_rfe = Pipeline([
    ('classifier', classifier)])

# %%
lgbm_rfe.fit(X_train_rfe, y_train)
# Out:
# Pipeline(steps=[('classifier',
#                  LGBMClassifier(metric='auc', objective='binary',
#                                 random_state=0, scale_pos_weight=9.75))])

# %%
# Predictions of target value for the validation set.
pred = lgbm_rfe.predict(X_test_rfe)

# Predictions of probabilities of the target value for the validation set.
pred_proba = lgbm_rfe.predict_proba(X_test_rfe)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.9200055152902182
# Accuracy of the model: 0.9485340251988266
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97    113837
#            1       0.37      0.66      0.47      4105
#
#     accuracy                           0.95    117942
#    macro avg       0.68      0.81      0.72    117942
# weighted avg       0.97      0.95      0.96    117942
#
#
# Confusion Matrix:
# [[109155   4682]
#  [  1388   2717]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve LightGBM')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ### 3.3. Lasso

# %% [markdown]
# #### Prueba 1

# %%
# Classifier.
classifier = lgb.LGBMClassifier(n_jobs=-1, random_state=0, boosting_type='gbdt', objective='binary', metric='auc',
                               learning_rate=0.1, scale_pos_weight=9.75)

lgbm_lasso1 = Pipeline([
    ('classifier', classifier)   
])

# %%
lgbm_lasso1.fit(X_train_lasso1, y_train)
# Out:
# Pipeline(steps=[('classifier',
#                  LGBMClassifier(metric='auc', objective='binary',
#                                 random_state=0, scale_pos_weight=9.75))])

# %%
# Predictions of target value for the validation set.
pred = lgbm_lasso1.predict(X_test_lasso1)

# Predictions of probabilities of the target value for the validation set.
pred_proba = lgbm_lasso1.predict_proba(X_test_lasso1)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.9146919056230761
# Accuracy of the model: 0.9427769581658781
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97    113837
#            1       0.33      0.65      0.44      4105
#
#     accuracy                           0.94    117942
#    macro avg       0.66      0.80      0.71    117942
# weighted avg       0.96      0.94      0.95    117942
#
#
# Confusion Matrix:
# [[108536   5301]
#  [  1448   2657]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve LightGBM')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# #### Prueba 2

# %%
# Classifier.
classifier = lgb.LGBMClassifier(n_jobs=-1, random_state=0, boosting_type='gbdt', objective='binary', metric='auc',
                               learning_rate=0.1, scale_pos_weight=9.75)

lgbm_lasso2 = Pipeline([
    ('classifier', classifier)   
])

# %%
lgbm_lasso2.fit(X_train_lasso2, y_train)
# Out:
# Pipeline(steps=[('classifier',
#                  LGBMClassifier(metric='auc', objective='binary',
#                                 random_state=0, scale_pos_weight=9.75))])

# %%
# Predictions of target value for the validation set.
pred = lgbm_lasso2.predict(X_test_lasso2)

# Predictions of probabilities of the target value for the validation set.
pred_proba = lgbm_lasso2.predict_proba(X_test_lasso2)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.9037932348448259
# Accuracy of the model: 0.939037832154788
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97    113837
#            1       0.31      0.63      0.42      4105
#
#     accuracy                           0.94    117942
#    macro avg       0.65      0.79      0.69    117942
# weighted avg       0.96      0.94      0.95    117942
#
#
# Confusion Matrix:
# [[108183   5654]
#  [  1536   2569]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve LightGBM')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ## 4. Modelos con técnicas para dataset desbalanceados

# %% [markdown]
# ### 4.1. SMOTE

# %%
# Classifier.
classifier = lgb.LGBMClassifier(n_jobs=-1, random_state=0, boosting_type='gbdt', objective='binary', metric='auc',
                               learning_rate=0.1, scale_pos_weight=6)

lgbm_smote = Pipeline([
    ('smote', SMOTE(random_state=12345)),
    ('classifier', classifier)
])

# %%
lgbm_smote.fit(X_train_rfe, y_train)
# Out:
# Pipeline(steps=[('smote', SMOTE(random_state=12345)),
#                 ('classifier',
#                  LGBMClassifier(metric='auc', objective='binary',
#                                 random_state=0, scale_pos_weight=6))])

# %%
# Predictions of target value for the validation set.
pred = lgbm_smote.predict(X_test_rfe)

# Predictions of probabilities of the target value for the validation set.
pred_proba = lgbm_smote.predict_proba(X_test_rfe)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.8948655821612664
# Accuracy of the model: 0.9208848417018535
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96    113837
#            1       0.26      0.67      0.37      4105
#
#     accuracy                           0.92    117942
#    macro avg       0.62      0.80      0.66    117942
# weighted avg       0.96      0.92      0.94    117942
#
#
# Confusion Matrix:
# [[105872   7965]
#  [  1366   2739]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve LightGBM')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ### 4.2. RandomUnderSampler

# %%
# Classifier.
classifier = lgb.LGBMClassifier(n_jobs=-1, random_state=0, boosting_type='gbdt', objective='binary', metric='auc',
                               learning_rate=0.1)

rus = RandomUnderSampler(random_state=42, sampling_strategy=0.4)

lgbm_rus = Pipeline([
    ('smote', rus),
    ('classifier', classifier)
])

# %%
lgbm_rus.fit(X_train_rfe, y_train)
# Out:
# Pipeline(steps=[('smote',
#                  RandomUnderSampler(random_state=42, sampling_strategy=0.4)),
#                 ('classifier',
#                  LGBMClassifier(metric='auc', objective='binary',
#                                 random_state=0))])

# %%
# Predictions of target value for the validation set.
pred = lgbm_rus.predict(X_test_rfe)

# Predictions of probabilities of the target value for the validation set.
pred_proba = lgbm_rus.predict_proba(X_test_rfe)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.9181261747449933
# Accuracy of the model: 0.9408183683505452
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97    113837
#            1       0.33      0.68      0.44      4105
#
#     accuracy                           0.94    117942
#    macro avg       0.66      0.81      0.71    117942
# weighted avg       0.97      0.94      0.95    117942
#
#
# Confusion Matrix:
# [[108175   5662]
#  [  1318   2787]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve LightGBM')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ### 4.3.SMOTETomek

# %%
# Classifier.
classifier = lgb.LGBMClassifier(n_jobs=-1, random_state=0, boosting_type='gbdt', objective='binary', metric='auc',
                               learning_rate=0.1, scale_pos_weight=6)

smt = SMOTETomek(random_state=42)

lgbm_smt = Pipeline([
    ('smote', smt),
    ('classifier', classifier)
])

# %%
lgbm_smt.fit(X_train_rfe, y_train)
# Out:
# Pipeline(steps=[('smote', SMOTETomek(random_state=42)),
#                 ('classifier',
#                  LGBMClassifier(metric='auc', objective='binary',
#                                 random_state=0, scale_pos_weight=6))])

# %%
# Predictions of target value for the validation set.
pred = lgbm_smt.predict(X_test_rfe)

# Predictions of probabilities of the target value for the validation set.
pred_proba = lgbm_smt.predict_proba(X_test_rfe)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.895103020187946
# Accuracy of the model: 0.9200030523477641
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96    113837
#            1       0.25      0.67      0.37      4105
#
#     accuracy                           0.92    117942
#    macro avg       0.62      0.80      0.66    117942
# weighted avg       0.96      0.92      0.94    117942
#
#
# Confusion Matrix:
# [[105747   8090]
#  [  1345   2760]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve LightGBM')
plt.legend()
# Show the plot
plt.show()
