# %% [markdown]
# ### Máster en Ciencia de Datos - CUNEF
#
# ### Trabajo Final de Máster
#
# ### Detección de transacciones fraudulentas con tarjetas bancarias usando técnicas de clasificación
#
# Alba Rodríguez Berenguel

# %% [markdown]
# En este notebook se va a construir el modelo Random Forest.
#
# Se van a realizar distintas pruebas para ver qué funciona mejor. Primero se realizará un modelo con el dataset completo y después con las distintas técnicas de feature selection que se han aplicado, para comprobar si se puede disminuir el número de variables y no afecta a la predicción. Después se probarán distintas técnicas para dataset desbalanceados como SMOTE, RandomUndersampler y SMOTETomek. Los pasos que se van a seguir son los siguientes:
#
# 1. Importación de librerías, funciones y datos.
# 2. Modelo inicial
# 3. Modelos con Feature Selection
# 4. Modelos con técnicas para dataset desbalanceados
# 5. Exportación del mejor modelo

# %% [markdown]
# ## 1. Importación de librerías, funciones y datos

# %%
# Import libraries.
import pandas as pd
import matplotlib.pyplot as plt
import pickle 
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.metrics import ConfusionMatrixDisplay, fbeta_score
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, accuracy_score, classification_report
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import RandomUnderSampler
#from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
import scikitplot as skplt
from sklearn.inspection import PartialDependenceDisplay
import warnings
warnings.filterwarnings('ignore')

# %%
# Function to evaluate the model.
def evaluate_model(ytest, ypred, ypred_proba = None):
    if ypred_proba is not None:
        print('ROC-AUC score of the model: {}'.format(roc_auc_score(ytest, ypred_proba[:, 1])))
    print('Accuracy of the model: {}\n'.format(accuracy_score(ytest, ypred)))
    print('Classification report: \n{}\n'.format(classification_report(ytest, ypred)))
    print('Confusion Matrix: \n{}\n'.format(confusion_matrix(y_test, pred)))

# %%
# Load data.
X_train = pd.read_parquet("../data/processed/X_train.parquet")
y_train = pd.read_parquet("../data/processed/y_train.parquet")['isfraud']

X_test = pd.read_parquet("../data/processed/X_test.parquet")
y_test = pd.read_parquet("../data/processed/y_test.parquet")['isfraud']

X_train_boruta = pd.read_parquet("../data/processed/X_train_boruta.parquet")
X_test_boruta = pd.read_parquet("../data/processed/X_test_boruta.parquet")

X_train_rfe = pd.read_parquet("../data/processed/X_train_rfe.parquet")
X_test_rfe = pd.read_parquet("../data/processed/X_test_rfe.parquet")

X_train_lasso1 = pd.read_parquet("../data/processed/X_train_lasso1.parquet")
X_test_lasso1 = pd.read_parquet("../data/processed/X_test_lasso1.parquet")

X_train_lasso2 = pd.read_parquet("../data/processed/X_train_lasso2.parquet")
X_test_lasso2 = pd.read_parquet("../data/processed/X_test_lasso2.parquet")

# %%
# Import the preprocessor.
preprocessor = pickle.load(open('../models/preprocessor.pickle', 'rb'))

# %% [markdown]
# ## 2. Modelo inicial

# %%
# Classifier.
classifier = RandomForestClassifier(random_state = 12345, n_jobs = -1, class_weight = 'balanced')

rf = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', classifier)   
])

# %%
rf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('catohe',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['productcd', 'card4',
#                                                    'card6', 'm4']),
#                                                  ('catbin',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=-1,
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OrdinalEncoder())]),
#                                                   ['m...
#                                                                    SimpleImputer(fill_value=-99,
#                                                                                  strategy='constant')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['transactionamt', 'c1', 'c3',
#                                                    'c5', 'd1', 'd3', 'd4',
#                                                    'd10', 'd11', 'd15', 'v3',
#                                                    'v4', 'v6', 'v8', 'v11',
#                                                    'v13', 'v17', 'v20', 'v23',
#                                                    'v26', 'v27', 'v30', 'v36',
#                                                    'v37', 'v40', 'v44', 'v47',
#                                                    'v48', 'v54', 'v56', ...])])),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced', n_jobs=-1,
#                                         random_state=12345))])

# %%
# Predictions of target value for the validation set.
pred = rf.predict(X_test)

# Predictions of probabilities of the target value for the validation set.
pred_proba = rf.predict_proba(X_test)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.9384612132716161
# Accuracy of the model: 0.9801682182767801
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99    113837
#            1       0.94      0.46      0.62      4105
#
#     accuracy                           0.98    117942
#    macro avg       0.96      0.73      0.80    117942
# weighted avg       0.98      0.98      0.98    117942
#
#
# Confusion Matrix:
# [[113717    120]
#  [  2219   1886]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Random Forest')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ## 3. Modelo con Feature Selection

# %% [markdown]
# ### 3.1. Boruta

# %%
# Classifier.
classifier = RandomForestClassifier(random_state = 12345, n_jobs = -1, class_weight = 'balanced')

rf_boruta = Pipeline([
    ('classifier', classifier)   
])

# %%
rf_boruta.fit(X_train_boruta, y_train)
# Out:
# Pipeline(steps=[('classifier',
#                  RandomForestClassifier(class_weight='balanced', n_jobs=-1,
#                                         random_state=12345))])

# %%
# Predictions of target value for the validation set.
pred = rf_boruta.predict(X_test_boruta)

# Predictions of probabilities of the target value for the validation set.
pred_proba = rf_boruta.predict_proba(X_test_boruta)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.9360337601329389
# Accuracy of the model: 0.9801258245578335
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99    113837
#            1       0.94      0.46      0.62      4105
#
#     accuracy                           0.98    117942
#    macro avg       0.96      0.73      0.80    117942
# weighted avg       0.98      0.98      0.98    117942
#
#
# Confusion Matrix:
# [[113720    117]
#  [  2227   1878]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Random Forest')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ### 3.2. RFE

# %%
# Classifier.
classifier = RandomForestClassifier(random_state = 12345, n_jobs = -1, class_weight = 'balanced')

rf_rfe = Pipeline([
    ('classifier', classifier)   
])

# %%
rf_rfe.fit(X_train_rfe, y_train)
# Out:
# Pipeline(steps=[('classifier',
#                  RandomForestClassifier(class_weight='balanced', n_jobs=-1,
#                                         random_state=12345))])

# %%
# Predictions of target value for the validation set.
pred = rf_rfe.predict(X_test_rfe)

# Predictions of probabilities of the target value for the validation set.
pred_proba = rf_rfe.predict_proba(X_test_rfe)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.9370090685790163
# Accuracy of the model: 0.9802106119957267
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99    113837
#            1       0.94      0.46      0.62      4105
#
#     accuracy                           0.98    117942
#    macro avg       0.96      0.73      0.80    117942
# weighted avg       0.98      0.98      0.98    117942
#
#
# Confusion Matrix:
# [[113718    119]
#  [  2215   1890]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Random Forest')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ### 3.3. Lasso

# %% [markdown]
# #### Prueba 1

# %%
# Classifier.
classifier = RandomForestClassifier(random_state = 12345, n_jobs = -1, class_weight = 'balanced')

rf_lasso1 = Pipeline([
    ('classifier', classifier)   
])

# %%
rf_lasso1.fit(X_train_lasso1, y_train)
# Out:
# Pipeline(steps=[('classifier',
#                  RandomForestClassifier(class_weight='balanced', n_jobs=-1,
#                                         random_state=12345))])

# %%
# Predictions of target value for the validation set.
pred = rf_lasso1.predict(X_test_lasso1)

# Predictions of probabilities of the target value for the validation set.
pred_proba = rf_lasso1.predict_proba(X_test_lasso1)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.935356856856798
# Accuracy of the model: 0.9781248410235539
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99    113837
#            1       0.93      0.40      0.56      4105
#
#     accuracy                           0.98    117942
#    macro avg       0.96      0.70      0.77    117942
# weighted avg       0.98      0.98      0.97    117942
#
#
# Confusion Matrix:
# [[113719    118]
#  [  2462   1643]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Random Forest')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# #### Prueba 2

# %%
# Classifier.
classifier = RandomForestClassifier(random_state = 12345, n_jobs = -1, class_weight = 'balanced')

rf_lasso2 = Pipeline([
    ('classifier', classifier)   
])

# %%
rf_lasso2.fit(X_train_lasso2, y_train)
# Out:
# Pipeline(steps=[('classifier',
#                  RandomForestClassifier(class_weight='balanced', n_jobs=-1,
#                                         random_state=12345))])

# %%
# Predictions of target value for the validation set.
pred = rf_lasso2.predict(X_test_lasso2)

# Predictions of probabilities of the target value for the validation set.
pred_proba = rf_lasso2.predict_proba(X_test_lasso2)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.9259645848948049
# Accuracy of the model: 0.9788455342456461
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99    113837
#            1       0.92      0.43      0.59      4105
#
#     accuracy                           0.98    117942
#    macro avg       0.95      0.71      0.79    117942
# weighted avg       0.98      0.98      0.98    117942
#
#
# Confusion Matrix:
# [[113688    149]
#  [  2346   1759]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Random Forest')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ## 4. Modelos con técnicas para dataset desbalanceados

# %% [markdown]
# ### 4.1. SMOTE

# %%
# Classifier.
classifier = RandomForestClassifier(random_state = 12345, n_jobs = -1, class_weight = 'balanced')

rf_smote = Pipeline([
    ('smote', SMOTE(random_state=12345)),
    ('classifier', classifier)
])

# %%
rf_smote.fit(X_train_rfe, y_train)
# Out:
# Pipeline(steps=[('smote', SMOTE(random_state=12345)),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced', n_jobs=-1,
#                                         random_state=12345))])

# %%
# Predictions of target value for the validation set.
pred = rf_smote.predict(X_test_rfe)

# Predictions of probabilities of the target value for the validation set.
pred_proba = rf_smote.predict_proba(X_test_rfe)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.9358078468008892
# Accuracy of the model: 0.9813382849197063
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99    113837
#            1       0.84      0.57      0.68      4105
#
#     accuracy                           0.98    117942
#    macro avg       0.91      0.78      0.83    117942
# weighted avg       0.98      0.98      0.98    117942
#
#
# Confusion Matrix:
# [[113407    430]
#  [  1771   2334]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Random Forest')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ### 4.2. RandomUnderSampler

# %%
# Classifier.
classifier = RandomForestClassifier(random_state = 12345, n_jobs = -1, class_weight = 'balanced')

rf_rus = Pipeline([
    ('smote', RandomUnderSampler(random_state=42, sampling_strategy=0.4)),
    ('classifier', classifier)
])

# %%
rf_rus.fit(X_train_rfe, y_train)
# Out:
# Pipeline(steps=[('smote',
#                  RandomUnderSampler(random_state=42, sampling_strategy=0.4)),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced', n_jobs=-1,
#                                         random_state=12345))])

# %%
# Predictions of target value for the validation set.
pred = rf_rus.predict(X_test_rfe)

# Predictions of probabilities of the target value for the validation set.
pred_proba = rf_rus.predict_proba(X_test_rfe)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.9351454887572063
# Accuracy of the model: 0.9577588984416069
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98    113837
#            1       0.43      0.71      0.54      4105
#
#     accuracy                           0.96    117942
#    macro avg       0.71      0.84      0.76    117942
# weighted avg       0.97      0.96      0.96    117942
#
#
# Confusion Matrix:
# [[110035   3802]
#  [  1180   2925]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Random Forest')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ### 4.3.SMOTETomek

# %%
# Classifier.
classifier = RandomForestClassifier(random_state = 12345, n_jobs = -1, class_weight = 'balanced')

smt = SMOTETomek(random_state=42, sampling_strategy=0.4)

rf_smt = Pipeline([
    ('smote', smt),
    ('classifier', classifier)
])

# %%
rf_smt.fit(X_train_rfe, y_train)
# Out:
# Pipeline(steps=[('smote', SMOTETomek(random_state=42, sampling_strategy=0.4)),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced', n_jobs=-1,
#                                         random_state=12345))])

# %%
# Predictions of target value for the validation set.
pred = rf_smt.predict(X_test_rfe)

# Predictions of probabilities of the target value for the validation set.
pred_proba = rf_smt.predict_proba(X_test_rfe)

# We evaluate the model with differents metrics with the function that we import.
evaluate_model(y_test, pred, pred_proba)
# Out:
# ROC-AUC score of the model: 0.9363321610229778
# Accuracy of the model: 0.9815841684895966
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99    113837
#            1       0.87      0.55      0.68      4105
#
#     accuracy                           0.98    117942
#    macro avg       0.93      0.77      0.83    117942
# weighted avg       0.98      0.98      0.98    117942
#
#
# Confusion Matrix:
# [[113513    324]
#  [  1848   2257]]

# %%
# Keep probabilities for the positive outcome only
yhat = pred_proba[:, 1]
# Calculate roc curves
fpr, tpr, thresholds = roc_curve(y_test, yhat)
# Plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Random Forest')
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# ## 5. Exportación del mejor modelo

# %%
with open('../models/random_forest.pickle', 'wb') as f:
    pickle.dump(rf_rus, f)

# %%
with open('../models/random_forest.pickle', 'rb') as f:
    rf_rus = pickle.load(f)
